# %%
import pandas as pd
import acquire_p
import matplotlib.pyplot as plt

# %% [markdown]
# Using your store items data:
#
#     Convert date column to datetime format.
#     Plot the distribution of sale_amount and item_price.
#     Set the index to be the datetime variable.
#     Add a 'month' and 'day of week' column to your dataframe.
#     Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
#     Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
zgulde = acquire_p.get_zgulde_data()

# %%
zgulde.head()
# Out:
#    sale_amount                      sale_date  store item_brand  \
# 0         13.0  Tue, 01 Jan 2013 00:00:00 GMT      1   Riceland
# 1         11.0  Wed, 02 Jan 2013 00:00:00 GMT      1   Riceland
# 2         14.0  Thu, 03 Jan 2013 00:00:00 GMT      1   Riceland
# 3         13.0  Fri, 04 Jan 2013 00:00:00 GMT      1   Riceland
# 4         10.0  Sat, 05 Jan 2013 00:00:00 GMT      1   Riceland
#
#                         item_name  item_price           store_address  \
# 0  Riceland American Jazmine Rice        0.84  12125 Alamo Ranch Pkwy
# 1  Riceland American Jazmine Rice        0.84  12125 Alamo Ranch Pkwy
# 2  Riceland American Jazmine Rice        0.84  12125 Alamo Ranch Pkwy
# 3  Riceland American Jazmine Rice        0.84  12125 Alamo Ranch Pkwy
# 4  Riceland American Jazmine Rice        0.84  12125 Alamo Ranch Pkwy
#
#     store_city store_state  store_zipcode
# 0  San Antonio          TX          78253
# 1  San Antonio          TX          78253
# ...

# %%
pd.to_datetime(zgulde.sale_date, infer_datetime_format=True).head()
# Out:
# 0   2013-01-01
# 1   2013-01-02
# 2   2013-01-03
# 3   2013-01-04
# 4   2013-01-05
# Name: sale_date, dtype: datetime64[ns]

# %%
pd.to_datetime(zgulde.sale_date, format= '%a, %d %b %Y %X %Z').head()
# Out:
# 0   2013-01-01 00:00:00+00:00
# 1   2013-01-02 00:00:00+00:00
# 2   2013-01-03 00:00:00+00:00
# 3   2013-01-04 00:00:00+00:00
# 4   2013-01-05 00:00:00+00:00
# Name: sale_date, dtype: datetime64[ns, GMT]

# %%
zgulde.sale_date = pd.to_datetime(zgulde.sale_date, format= '%a, %d %b %Y %X %Z')

# %%
zgulde.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 913000 entries, 0 to 912999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sale_amount    913000 non-null  float64
#  1   sale_date      913000 non-null  datetime64[ns, GMT]
#  2   store          913000 non-null  int64
#  3   item_brand     913000 non-null  object
#  4   item_name      913000 non-null  object
#  5   item_price     913000 non-null  float64
#  6   store_address  913000 non-null  object
#  7   store_city     913000 non-null  object
#  8   store_state    913000 non-null  object
#  9   store_zipcode  913000 non-null  int64
# dtypes: datetime64[ns, GMT](1), float64(2), int64(2), object(5)
# memory usage: 76.6+ MB

# %%
zgulde
# Out:
#         sale_amount                 sale_date  store item_brand  \
# 0              13.0 2013-01-01 00:00:00+00:00      1   Riceland
# 1              11.0 2013-01-02 00:00:00+00:00      1   Riceland
# 2              14.0 2013-01-03 00:00:00+00:00      1   Riceland
# 3              13.0 2013-01-04 00:00:00+00:00      1   Riceland
# 4              10.0 2013-01-05 00:00:00+00:00      1   Riceland
# ...             ...                       ...    ...        ...
# 912995         63.0 2017-12-27 00:00:00+00:00     10     Choice
# 912996         59.0 2017-12-28 00:00:00+00:00     10     Choice
# 912997         74.0 2017-12-29 00:00:00+00:00     10     Choice
# 912998         62.0 2017-12-30 00:00:00+00:00     10     Choice
# 912999         82.0 2017-12-31 00:00:00+00:00     10     Choice
#
#                                                 item_name  item_price  \
# 0                          Riceland American Jazmine Rice        0.84
# ...

# %%
zgulde.plot(x = 'sale_amount', y = 'item_price')
# Out:
# <AxesSubplot:xlabel='sale_amount'>

# %%
zgulde.set_index('sale_date')
# Out:
#                            sale_amount  store item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0      1   Riceland
# 2013-01-02 00:00:00+00:00         11.0      1   Riceland
# 2013-01-03 00:00:00+00:00         14.0      1   Riceland
# 2013-01-04 00:00:00+00:00         13.0      1   Riceland
# 2013-01-05 00:00:00+00:00         10.0      1   Riceland
# ...                                ...    ...        ...
# 2017-12-27 00:00:00+00:00         63.0     10     Choice
# 2017-12-28 00:00:00+00:00         59.0     10     Choice
# 2017-12-29 00:00:00+00:00         74.0     10     Choice
# 2017-12-30 00:00:00+00:00         62.0     10     Choice
# 2017-12-31 00:00:00+00:00         82.0     10     Choice
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-02 00:00:00+00:00                     Riceland American Jazmine Rice
# ...

# %%
plt.hist(zgulde.sale_amount)
# Out:
# (array([1.41304e+05, 3.09995e+05, 2.32808e+05, 1.36482e+05, 6.28770e+04,
#         2.25590e+04, 5.86500e+03, 1.00900e+03, 9.60000e+01, 5.00000e+00]),
#  array([  0. ,  23.1,  46.2,  69.3,  92.4, 115.5, 138.6, 161.7, 184.8,
#         207.9, 231. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(zgulde.item_price)
# Out:
# (array([109560.,  54780., 109560.,  91300.,  54780., 127820.,  54780.,
#         109560., 109560.,  91300.]),
#  array([0.6  , 1.504, 2.408, 3.312, 4.216, 5.12 , 6.024, 6.928, 7.832,
#         8.736, 9.64 ]),
#  <BarContainer object of 10 artists>)

# %%
zgulde.set_index('sale_date', inplace = True)

# %%
zgulde.index
# Out:
# DatetimeIndex(['2013-01-01 00:00:00+00:00', '2013-01-02 00:00:00+00:00',
#                '2013-01-03 00:00:00+00:00', '2013-01-04 00:00:00+00:00',
#                '2013-01-05 00:00:00+00:00', '2013-01-06 00:00:00+00:00',
#                '2013-01-07 00:00:00+00:00', '2013-01-08 00:00:00+00:00',
#                '2013-01-09 00:00:00+00:00', '2013-01-10 00:00:00+00:00',
#                ...
#                '2017-12-22 00:00:00+00:00', '2017-12-23 00:00:00+00:00',
#                '2017-12-24 00:00:00+00:00', '2017-12-25 00:00:00+00:00',
#                '2017-12-26 00:00:00+00:00', '2017-12-27 00:00:00+00:00',
#                '2017-12-28 00:00:00+00:00', '2017-12-29 00:00:00+00:00',
#                '2017-12-30 00:00:00+00:00', '2017-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, GMT]', name='sale_date', length=913000, freq=None)

# %%
zgulde['month'] = zgulde.index.month_name()

# %%
zgulde.month.value_counts()
# Out:
# January      77500
# March        77500
# May          77500
# July         77500
# August       77500
# October      77500
# December     77500
# April        75000
# June         75000
# September    75000
# November     75000
# February     70500
# Name: month, dtype: int64

# %%
zgulde['weekday'] = zgulde.index.day_name()

# %%
zgulde.head()
# Out:
#                            sale_amount  store item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0      1   Riceland
# 2013-01-02 00:00:00+00:00         11.0      1   Riceland
# 2013-01-03 00:00:00+00:00         14.0      1   Riceland
# 2013-01-04 00:00:00+00:00         13.0      1   Riceland
# 2013-01-05 00:00:00+00:00         10.0      1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-02 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-03 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-04 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-05 00:00:00+00:00  Riceland American Jazmine Rice        0.84
#
#                                     store_address   store_city store_state  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio          TX
# ...

# %%
zgulde['sales_amount'] = zgulde.sale_amount * zgulde.item_price

# %%
zgulde.head()
# Out:
#                            sale_amount  store item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0      1   Riceland
# 2013-01-02 00:00:00+00:00         11.0      1   Riceland
# 2013-01-03 00:00:00+00:00         14.0      1   Riceland
# 2013-01-04 00:00:00+00:00         13.0      1   Riceland
# 2013-01-05 00:00:00+00:00         10.0      1   Riceland
#
#                                                 item_name  item_price  \
# sale_date
# 2013-01-01 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-02 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-03 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-04 00:00:00+00:00  Riceland American Jazmine Rice        0.84
# 2013-01-05 00:00:00+00:00  Riceland American Jazmine Rice        0.84
#
#                                     store_address   store_city store_state  \
# sale_date
# 2013-01-01 00:00:00+00:00  12125 Alamo Ranch Pkwy  San Antonio          TX
# ...

# %% [markdown]
# # Make and test functions
# I will test them on the german dataset so below is:
#
# stores_data_set #6 and german_data_set(#1-6)

# %%
ger = pd.read_csv('ger_elec.csv')

# %%
ger
# Out:
#       Unnamed: 0        Date  Consumption     Wind   Solar  Wind+Solar
# 0              0  2006-01-01   1069.18400      NaN     NaN         NaN
# 1              1  2006-01-02   1380.52100      NaN     NaN         NaN
# 2              2  2006-01-03   1442.53300      NaN     NaN         NaN
# 3              3  2006-01-04   1457.21700      NaN     NaN         NaN
# 4              4  2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...         ...          ...      ...     ...         ...
# 4378        4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379        4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380        4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381        4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382        4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 6 columns]

# %%
ger.describe().round(2)
# Out:
#        Unnamed: 0  Consumption     Wind    Solar  Wind+Solar
# count     4383.00      4383.00  2920.00  2188.00     2187.00
# mean      2191.00      1338.68   164.81    89.26      272.66
# std       1265.41       165.78   143.69    58.55      146.32
# min          0.00       842.40     5.76     1.97       21.48
# 25%       1095.50      1217.86    62.35    35.18      172.19
# 50%       2191.00      1367.12   119.10    86.41      240.99
# 75%       3286.50      1457.76   217.90   135.07      338.99
# max       4382.00      1709.57   826.28   241.58      851.56

# %%
# There are no 0s in the data set. and all the NaNs are early in the data. #
# i am concluding that the NaNs are 0s from before 'green' energy became a more popular option
#

# %%
ger.fillna(value = 0, inplace = True)

# %%
ger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   4383 non-null   int64
#  1   Date         4383 non-null   datetime64[ns]
#  2   Consumption  4383 non-null   float64
#  3   Wind         4383 non-null   float64
#  4   Solar        4383 non-null   float64
#  5   Wind+Solar   4383 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 205.6 KB

# %%
def fillna(df, values):
    df.fillna(value=values, inplace =True)
    return df

# %%
def convert_time(col):
    col = pd.to_datetime(col, infer_datetime_format=True)
    return col

# %%
ger.Date = convert_time(ger.Date)

# %%
ger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   4383 non-null   int64
#  1   Date         4383 non-null   datetime64[ns]
#  2   Consumption  4383 non-null   float64
#  3   Wind         2920 non-null   float64
#  4   Solar        2188 non-null   float64
#  5   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 205.6 KB

# %%
# worked

# %%
def convert_index(df, col):
    df = df.set_index(col)
    return df

# %%
ger = convert_index(ger, ger.Date)

# %%
ger.head()
# Out:
#             Unnamed: 0       Date  Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01           0 2006-01-01     1069.184   0.0    0.0         0.0
# 2006-01-02           1 2006-01-02     1380.521   0.0    0.0         0.0
# 2006-01-03           2 2006-01-03     1442.533   0.0    0.0         0.0
# 2006-01-04           3 2006-01-04     1457.217   0.0    0.0         0.0
# 2006-01-05           4 2006-01-05     1477.131   0.0    0.0         0.0

# %%
def hist(col):
    for c in col:
        plt.figure()
        plt.hist(col)
        plt.show()

# %%
col = ger[['Wind', 'Solar', 'Wind+Solar']]

# %%
hist(col)

# %%
def hist_enum(df, col):
    plt.figure(figsize=(16, 3))

    for i, col in enumerate(col):

        # i starts at 0, but plot nos should start at 1
        plot_number = i + 1

        # Create subplot.
        # plt.subplot(row X col, where?)
        plt.subplot(1,4,plot_number)

        # Title with column name.
        plt.title(col)

        # Display histogram for column.
        df[col].hist(bins=5, edgecolor='black')

        # Hide gridlines.
        plt.grid(False)

# %%
hist_enum(ger, col)

# %%
def time_metric_col(df):
    df['month'] = df.index.month_name()
    df['weekday'] = df.index.day_name()
    df['year'] = df.index.year
    return df

# %%
ger = time_metric_col(ger)
ger.head()
# Out:
#             Unnamed: 0       Date  Consumption     Wind   Solar  Wind+Solar  \
# Date
# 2006-01-01           0 2006-01-01   1069.18400    0.000   0.000       0.000
# 2006-01-02           1 2006-01-02   1380.52100    0.000   0.000       0.000
# 2006-01-03           2 2006-01-03   1442.53300    0.000   0.000       0.000
# 2006-01-04           3 2006-01-04   1457.21700    0.000   0.000       0.000
# 2006-01-05           4 2006-01-05   1477.13100    0.000   0.000       0.000
# ...                ...        ...          ...      ...     ...         ...
# 2017-12-27        4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28        4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29        4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30        4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31        4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
#                month    weekday  year
# Date
# ...

# %%
def col_mult_function(df, col1, col2):
    df['product'] = col1 *col2
    return df

# %%
l = col_mult_function(zgulde, zgulde.item_price, zgulde.sale_amount)
l
# Out:
#                            sale_amount  store item_brand  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0      1   Riceland
# 2013-01-02 00:00:00+00:00         11.0      1   Riceland
# 2013-01-03 00:00:00+00:00         14.0      1   Riceland
# 2013-01-04 00:00:00+00:00         13.0      1   Riceland
# 2013-01-05 00:00:00+00:00         10.0      1   Riceland
# ...                                ...    ...        ...
# 2017-12-27 00:00:00+00:00         63.0     10     Choice
# 2017-12-28 00:00:00+00:00         59.0     10     Choice
# 2017-12-29 00:00:00+00:00         74.0     10     Choice
# 2017-12-30 00:00:00+00:00         62.0     10     Choice
# 2017-12-31 00:00:00+00:00         82.0     10     Choice
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-02 00:00:00+00:00                     Riceland American Jazmine Rice
# ...
